# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\heart\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.4; however, version 24.1.2 is available.
# You should consider upgrading via the 'c:\Users\heart\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt

# %%
plt.title('My First Graph')
# Out:
# Text(0.5, 1.0, 'My First Graph')

# %%
x_axis = [1,2,3]
y_axis = [4,5,6]
plt.title('My First Graph')
plt.plot(x_axis,y_axis,'r')
#'r' is used to plot color red

# %%
x_axis = [1,2,3]
y_axis = [4,5,6]
plt.title('Graph with Label')
plt.xlabel('x_axis')
plt.ylabel('y_axis')
plt.plot(x_axis,y_axis)

# %%
x1 = [1,2,3]
y1 = [1,2,3]

x2 = [1,2,3]
y2 = [3,2,1]

plt.title('Graph with Label')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x1,y1,'r')
plt.plot(x2,y2,'g')
plt.legend(['upward','downward'])

# %% [markdown]
# Bar Plot --- plt.bar(values, height, width) ----height can be single value or the list of values ,  width is optional

# %%
import matplotlib.pyplot as plt

# %%
values = [12,3,4,10]
plt.bar(values,2)
# Out:
# <BarContainer object of 4 artists>

# %%
values = [12,3,4,10]
plt.bar(values,[1])
# Out:
# <BarContainer object of 4 artists>

# %%
values = [10,20,30,40]
plt.bar(values,[1,2,2,1],5)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Piechart

# %%
values = [12,3,4,10]
plt.pie(values)
# Out:
# ([<matplotlib.patches.Wedge at 0x269f1d4b580>,
# ...
#  [Text(0.29428110789865214, 1.0599050096748963, ''),
#   Text(-1.0742827141232627, 0.23646701701496603, ''),
#   Text(-0.9425427284230392, -0.5671095177272668, ''),
#   Text(0.5152495212782517, -0.9718631235017268, '')])

# %%
values = [12,3,4,10]
plt.pie(values, labels=['a','b','c','d'])
# Out:
# ([<matplotlib.patches.Wedge at 0x269f672a260>,
# ...
#  [Text(0.29428110789865214, 1.0599050096748963, 'a'),
#   Text(-1.0742827141232627, 0.23646701701496603, 'b'),
#   Text(-0.9425427284230392, -0.5671095177272668, 'c'),
#   Text(0.5152495212782517, -0.9718631235017268, 'd')])

# %%
values = [12,3,4,10]
plt.pie(values, labels=['a','b','c','d'], explode=[0,0.2,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x269f67718a0>,
# ...
#  [Text(0.29428110789865214, 1.0599050096748963, 'a'),
#   Text(-1.269606843963856, 0.2794610201085962, 'b'),
#   Text(-0.9425427284230392, -0.5671095177272668, 'c'),
#   Text(0.5152495212782517, -0.9718631235017268, 'd')])

# %%
values = [12,3,4,10]
plt.pie(values, labels=['a','b','c','d'], explode=[0.2,0.2,0.2,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x269f68037c0>,
# ...
#  [Text(0.3477867638802252, 1.2526150114339685, 'a'),
#   Text(-1.269606843963856, 0.2794610201085962, 'b'),
#   Text(-1.1139141335908644, -0.6702203391322245, 'c'),
#   Text(0.5152495212782517, -0.9718631235017268, 'd')])

# %%
values = [12,3,4,10]
plt.pie(values, labels=['a','b','c','d'], explode=[0.2,0.2,0.2,0], colors=['r','g','b','y'])
# Out:
# ([<matplotlib.patches.Wedge at 0x269f68c65c0>,
# ...
#  [Text(0.3477867638802252, 1.2526150114339685, 'a'),
#   Text(-1.269606843963856, 0.2794610201085962, 'b'),
#   Text(-1.1139141335908644, -0.6702203391322245, 'c'),
#   Text(0.5152495212782517, -0.9718631235017268, 'd')])
